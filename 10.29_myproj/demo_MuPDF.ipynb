# %% [raw]
# https://pymupdf.readthedocs.io/en/latest/tutorial.html
# 因为 MuPDF 不仅支持 PDF，还支持 XPS、OpenXPS、CBZ、CBR、FB2 和 EPUB 格式，所以 PyMuPDF 也支持。
#
# 处理论文的表单部分

# %%
import fitz

doc = fitz.open("ch1.pdf")
toc = doc.get_toc()
toc
# Out:
# [[1, '摘要', 4],
#  [1, 'Abstract', 5],
#  [1, '引言', 10],
#  [2, '(一)研究缘起', 10],
#  [3, '1.培养幼儿合作能力的重要意义', 10],
#  [3, '2.角色游戏对培养幼儿合作能力具有独特价值', 11],
#  [2, '(二)研究意义', 12],
#  [3, '1.理论意义', 12],
#  [3, '2.实践意义', 13],
#  [2, '(三)文献综述', 13],
#  [3, '1.核心概念界定', 13],
#  [3, '2.国内幼儿合作能力与角色游戏研究综述', 15],
#  [3, '3.国外幼儿合作能力与角色游戏研究综述', 19],
#  [3, '4.综合述评', 22],
#  [2, '(四)理论基础', 23],
#  [3, '1.班杜拉社会学习理论', 23],
#  [3, '2.米德的角色理论', 24],
#  [3, '3.罗杰斯人本主义理论', 25],
#  [1, '一、研究设计', 27],
#  [2, '(一)研究目的', 27],
#  [2, '(二)研究内容', 27],
#  [2, '(三)研究对象', 28],
#  [2, '(四)研究方法', 28],
#  [2, '(五)研究过程', 30],
#  [1, '二、角色游戏中幼儿合作能力培养的现状分析', 32],
#  [2, '(一)实施的基本情况', 32],
#  [2, '(二)现状存在的问题', 33],
#  [3, '1.角色游戏主题单一,难以激发幼儿的合作意识', 33],
#  [3, '2.角色游戏环境创设固化,缺少幼儿合作的契机', 34],
#  [3, '3.角色游戏中教师的组织与指导策略缺乏有效性', 36],
#  [1, '三、基于幼儿合作能力培养的角色游戏活动设计', 39],
#  [2, '(一)设计理念', 39],
#  [3, '1.以观察为起点,重视榜样作用', 39],
#  [3, '2.以角色为动机,强调互动协调', 39],
#  [3, '3.以经验为中心,尊重主体地位', 40],
#  [2, '(二)设计原则', 40],
#  [3, '1.生活性', 40],
# ...

# %% [markdown]
# 将 PyMuPDF 集成到您的大型语言模型 （LLM） 框架和整体 RAG（检索增强生成）解决方案中，提供了最快、最可靠的文档数据交付方式。
# https://pymupdf.readthedocs.io/en/latest/rag.html
#
# 案例：https://artifex.com/blog/creating-a-rag-chatbot-with-chatgpt-and-pymupdf
# 调用 PyMuPDF 读取 PDF 内容的函数针对小尺寸进行了优化：它只会读取表格行 - 而不是页面的全文。

# %%
for field in page.widgets():
    print(field)

# %%
for page in doc:
    print(page)

# %%
处理论文的文字部分:pypdf等
